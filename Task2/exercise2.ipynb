# %% [markdown]
# # Deep learning applications in medical imaging: Ex.2
#
# Due date: 9/5/23
#
# You can submit as one student or in pairs (two students).
#
# Submitted by: [ **Rafael Ashurov 312054711, Corinne Golan 302276159** ]

# %% [markdown]
# # 1. Buidling a simple convolution neural network.
#
# Your task is to build a classifier to classify X-ray images into 4 categories: Normal, Cvoid-19 infection, Lung opacity, Viral pneumonia.
#
# If you want to look at the X-ray images in the data set you can download them from here:
# http://dl.dropboxusercontent.com/s/6hq5t0sbbx6n1g2/medical_xray.zip?dl=0
# Or you can look at the environment files in Google Colab after running the second cell (double click on an image to view it).
#
# *Notice that unfortantly we don't have many samples but try to do your best and may the force be with you.
#
# - If you are using Google Colab switch to GPU mode by selecting "Runtime" on the top menu and then "Change runtime type", in "Hardware accelerator" select "GPU".
#
# - If you are using Google Colab and suddenly encounter unexpected problems (even sudden drop in accuracy) try selecting in the top menu "Runtime"->"Disconnect and delete runtime", after that run all the cells again.
#
# - First run the code cells below which do the following: contain the necessary imports, retrieve the data, process it into train and test data sets. Look at the comments and verify you get the prints right to verify all works fine.

# %%
import pathlib
import os
import matplotlib.pyplot as plt
import numpy as np
import requests, zipfile, io
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, Input
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from PIL import Image, ImageOps

# %%
#Download dataset from URL as zip and extract its content to Google Colab environment
r = requests.get('http://dl.dropboxusercontent.com/s/6hq5t0sbbx6n1g2/medical_xray.zip?dl=0', stream=True)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
#Iterate the sub folder and print the classes - *total 4 classes*
# You should see the following print:
# ['covid', 'lung_opacity', 'normal', 'viral_pneumonia']

PATH = '/content/medical_xray'

p = pathlib.Path(PATH)

labels = [x.parts[-1] for x in p.iterdir()]

num_classes = len(labels)
labels.sort()
print(labels)
# Out:
# ['covid', 'lung_opacity', 'normal', 'viral_pneumonia']

# %%
# Print number of samples for each class - *about 224 samples*
# You should see the following prints:
# covid 224
# lung_opacity 224
# normal 224
# viral_pneumonia 224

files_path = []
files_labels = []

for root, dirs, files in os.walk(PATH):
  p = pathlib.Path(root)
  
  for file in files:
    files_path.append(root + '/' + file)
    files_labels.append(p.parts[-1])

label_cnt = []

for label in labels:
  print(label, files_labels.count(label))
  label_cnt.append(files_labels.count(label))
# Out:
# covid 224
# lung_opacity 224
# normal 224
# viral_pneumonia 224

# %%
# Process the data, split it to 80% of the samples for train, 20% test.

file_path = []
file_label = []
for root,dirs,files in os.walk(PATH):
    p = pathlib.Path(root)
    for file in files:
        file_path.append(root+"/"+file)
        file_label.append(p.parts[-1])

X = []
y = []
for path in file_path:
    img = Image.open(path)
    img = ImageOps.grayscale(img)
    if (img.width or img.height) != 64:
        img = img.resize((64,64))
    img_arr = np.asarray(img,dtype  = np.int16)
    X.append(img_arr)
X = np.array(X)
y = np.array(file_label)

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 1)

y_train = list(map(lambda x : labels.index(x),y_train))
y_train = np.array(y_train)

y_test = list(map(lambda x: labels.index(x),y_test))
y_test = np.array(y_test)

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

#Print train shape and number of train and test samples, you should see the following prints:
# x_train shape: (716, 64, 64, 1)
# 716 train samples
# 180 test sample
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")
# Out:
# x_train shape: (716, 64, 64, 1)
# 716 train samples
# 180 test samples

# %% [markdown]
# - Build a simple convolution neural network (like we saw on class) with a maximum of 5 layers or less (Only Conv2D and Dense counts as layers).
#
# - You can **only use** the following components: Conv2D, MaxPooling2D, Flatten, Dense.
#
# - Use sgd_momentum with learning_rate=0.01, momentum=0.9, use loss='sparse_categorical_crossentropy'
#
# - Run for 50 epochs, take approxmatly the 5 best epochs in terms of accuracy and write their average as the result, you should get a result of at least 80% accuracy.
#
# - Take notice about the input shape, number of classes and batch size in your code. Also notice that accuracy is not the only measure of success  here - meaning you can choose wrong values and stil get a good accuracy (in this case I will not give a you full score).

# %%
def print_avrg_val_acc (history):
    # Find the 5 best epochs in terms of validation accuracy
    val_acc = history.history['val_accuracy']
    best_epochs = sorted(val_acc, reverse=True)[:5]
    avg_val_acc = sum(best_epochs)/5
    print("Average validation accuracy of the 5 best epochs: ", avg_val_acc)

# %%
from tensorflow.keras.optimizers import SGD

# Define the model
model1 = Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64,64,1)),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(units=256, activation='relu'),
    Dense(units=4, activation='softmax')
])
print(model1.summary())

# Compile the model using gradient descent WITH MOMENTUM:
sgd_momentum = SGD(learning_rate=0.01, momentum=0.9)
model1.compile(optimizer=sgd_momentum, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model1.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test))

print_avrg_val_acc(history)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 62, 62, 32)        320
#
#  max_pooling2d_12 (MaxPoolin  (None, 31, 31, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 29, 29, 64)        18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 12544)             0
#
#  dense_10 (Dense)            (None, 256)               3211520
#
#  dense_11 (Dense)            (None, 4)                 1028
#
# =================================================================
# Total params: 3,231,364
# Trainable params: 3,231,364
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 23/23 [==============================] - 1s 21ms/step - loss: 1.3620 - accuracy: 0.3254 - val_loss: 1.3141 - val_accuracy: 0.2778
# Epoch 2/50
# 23/23 [==============================] - 0s 9ms/step - loss: 1.1681 - accuracy: 0.4581 - val_loss: 1.1070 - val_accuracy: 0.5222
# Epoch 3/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.9256 - accuracy: 0.6425 - val_loss: 0.9046 - val_accuracy: 0.6056
# Epoch 4/50
# 23/23 [==============================] - 0s 8ms/step - loss: 0.8915 - accuracy: 0.6341 - val_loss: 0.8881 - val_accuracy: 0.6778
# Epoch 5/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7584 - accuracy: 0.7081 - val_loss: 0.7898 - val_accuracy: 0.6833
# Epoch 6/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7058 - accuracy: 0.7109 - val_loss: 0.7419 - val_accuracy: 0.6944
# Epoch 7/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6430 - accuracy: 0.7500 - val_loss: 0.6892 - val_accuracy: 0.6889
# Epoch 8/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6118 - accuracy: 0.7668 - val_loss: 0.6839 - val_accuracy: 0.7056
# Epoch 9/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5429 - accuracy: 0.7919 - val_loss: 0.7054 - val_accuracy: 0.7222
# Epoch 10/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5213 - accuracy: 0.7989 - val_loss: 0.6581 - val_accuracy: 0.6833
# Epoch 11/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5154 - accuracy: 0.7975 - val_loss: 0.6253 - val_accuracy: 0.7389
# Epoch 12/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4670 - accuracy: 0.8296 - val_loss: 0.7007 - val_accuracy: 0.7056
# Epoch 13/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4292 - accuracy: 0.8380 - val_loss: 0.7032 - val_accuracy: 0.7000
# Epoch 14/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3895 - accuracy: 0.8478 - val_loss: 0.7013 - val_accuracy: 0.7500
# Epoch 15/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3449 - accuracy: 0.8673 - val_loss: 0.7259 - val_accuracy: 0.7278
# Epoch 16/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3605 - accuracy: 0.8631 - val_loss: 0.7091 - val_accuracy: 0.7444
# Epoch 17/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3092 - accuracy: 0.8813 - val_loss: 0.6639 - val_accuracy: 0.7667
# Epoch 18/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2496 - accuracy: 0.9036 - val_loss: 0.6605 - val_accuracy: 0.7611
# Epoch 19/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2446 - accuracy: 0.9162 - val_loss: 0.7054 - val_accuracy: 0.7556
# Epoch 20/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2233 - accuracy: 0.9176 - val_loss: 0.8826 - val_accuracy: 0.7167
# Epoch 21/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2164 - accuracy: 0.9134 - val_loss: 0.7848 - val_accuracy: 0.7667
# Epoch 22/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1401 - accuracy: 0.9455 - val_loss: 0.8321 - val_accuracy: 0.7778
# Epoch 23/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1455 - accuracy: 0.9539 - val_loss: 0.8348 - val_accuracy: 0.7556
# Epoch 24/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1978 - accuracy: 0.9260 - val_loss: 0.9078 - val_accuracy: 0.7778
# Epoch 25/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1602 - accuracy: 0.9358 - val_loss: 0.8977 - val_accuracy: 0.7778
# Epoch 26/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1673 - accuracy: 0.9288 - val_loss: 0.8419 - val_accuracy: 0.7556
# Epoch 27/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1285 - accuracy: 0.9567 - val_loss: 0.9013 - val_accuracy: 0.7500
# Epoch 28/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0745 - accuracy: 0.9791 - val_loss: 1.0376 - val_accuracy: 0.7778
# Epoch 29/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.1010 - accuracy: 0.9651 - val_loss: 0.9054 - val_accuracy: 0.7889
# Epoch 30/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0539 - accuracy: 0.9818 - val_loss: 0.9576 - val_accuracy: 0.7944
# Epoch 31/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0698 - accuracy: 0.9763 - val_loss: 1.2885 - val_accuracy: 0.7333
# Epoch 32/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1020 - accuracy: 0.9623 - val_loss: 0.9395 - val_accuracy: 0.7889
# Epoch 33/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0336 - accuracy: 0.9930 - val_loss: 0.9797 - val_accuracy: 0.7944
# Epoch 34/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0270 - accuracy: 0.9972 - val_loss: 1.0445 - val_accuracy: 0.7778
# Epoch 35/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 0.9986 - val_loss: 1.0800 - val_accuracy: 0.8000
# Epoch 36/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 1.1165 - val_accuracy: 0.8111
# Epoch 37/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.1180 - val_accuracy: 0.8000
# Epoch 38/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.1946 - val_accuracy: 0.8000
# Epoch 39/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.2146 - val_accuracy: 0.8056
# Epoch 40/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.2557 - val_accuracy: 0.8000
# Epoch 41/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.2483 - val_accuracy: 0.8000
# Epoch 42/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.2618 - val_accuracy: 0.7944
# Epoch 43/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.2793 - val_accuracy: 0.7944
# Epoch 44/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3130 - val_accuracy: 0.7944
# Epoch 45/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.3196 - val_accuracy: 0.8000
# Epoch 46/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.3295 - val_accuracy: 0.8000
# Epoch 47/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.3437 - val_accuracy: 0.8000
# Epoch 48/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.3602 - val_accuracy: 0.8056
# Epoch 49/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3617 - val_accuracy: 0.7944
# Epoch 50/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.3789 - val_accuracy: 0.7944
# Average validation accuracy of the 5 best epochs:  0.8044444561004639

# %% [markdown]
# - Try to improve your result by at least 2% with any of the methods we saw in class, beside augmentation and beside changing the number of layers or number/sizes of the kernels (since those methods are found in the next questions).

# %%
from keras.layers import BatchNormalization

# Define the model
model2 = Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64,64,1)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(units=256, activation='relu'),
    Dense(units=4, activation='softmax')
])
print(model2.summary())
sgd_momentum = SGD(learning_rate=0.005, momentum=0.9)
model2.compile(optimizer=sgd_momentum, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history2 = model2.fit(x_train, y_train, epochs=50, batch_size=16, validation_data=(x_test, y_test))

print_avrg_val_acc(history2)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 62, 62, 32)        320
#
#  batch_normalization_14 (Bat  (None, 62, 62, 32)       128
#  chNormalization)
#
#  max_pooling2d_18 (MaxPoolin  (None, 31, 31, 32)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 29, 29, 64)        18496
#
#  batch_normalization_15 (Bat  (None, 29, 29, 64)       256
#  chNormalization)
#
#  max_pooling2d_19 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 12544)             0
#
#  dense_16 (Dense)            (None, 256)               3211520
#
#  dense_17 (Dense)            (None, 4)                 1028
#
# =================================================================
# Total params: 3,231,748
# Trainable params: 3,231,556
# Non-trainable params: 192
# _________________________________________________________________
# None
# Epoch 1/50
# 45/45 [==============================] - 1s 10ms/step - loss: 1.4263 - accuracy: 0.6006 - val_loss: 1.6169 - val_accuracy: 0.3056
# Epoch 2/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.8252 - accuracy: 0.7137 - val_loss: 1.2825 - val_accuracy: 0.4667
# Epoch 3/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.5908 - accuracy: 0.7682 - val_loss: 1.8829 - val_accuracy: 0.4611
# Epoch 4/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4507 - accuracy: 0.8268 - val_loss: 1.5455 - val_accuracy: 0.6222
# Epoch 5/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.3521 - accuracy: 0.8506 - val_loss: 1.7095 - val_accuracy: 0.5611
# Epoch 6/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.2798 - accuracy: 0.8939 - val_loss: 1.6982 - val_accuracy: 0.6056
# Epoch 7/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.2617 - accuracy: 0.9050 - val_loss: 1.7570 - val_accuracy: 0.5889
# Epoch 8/50
# 45/45 [==============================] - 0s 8ms/step - loss: 0.2351 - accuracy: 0.9064 - val_loss: 1.4249 - val_accuracy: 0.6278
# Epoch 9/50
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1825 - accuracy: 0.9302 - val_loss: 1.0415 - val_accuracy: 0.6889
# Epoch 10/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.2387 - accuracy: 0.9204 - val_loss: 0.9662 - val_accuracy: 0.7889
# Epoch 11/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.1801 - accuracy: 0.9330 - val_loss: 0.7754 - val_accuracy: 0.7556
# Epoch 12/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.1057 - accuracy: 0.9539 - val_loss: 0.7785 - val_accuracy: 0.7944
# Epoch 13/50
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0786 - accuracy: 0.9707 - val_loss: 0.9860 - val_accuracy: 0.7611
# Epoch 14/50
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0580 - accuracy: 0.9888 - val_loss: 0.8201 - val_accuracy: 0.7833
# Epoch 15/50
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0239 - accuracy: 0.9916 - val_loss: 0.8566 - val_accuracy: 0.8056
# Epoch 16/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0096 - accuracy: 0.9986 - val_loss: 0.8356 - val_accuracy: 0.8167
# Epoch 17/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.8684 - val_accuracy: 0.8278
# Epoch 18/50
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.8490 - val_accuracy: 0.8389
# Epoch 19/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.8356 - val_accuracy: 0.8389
# Epoch 20/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8484 - val_accuracy: 0.8333
# Epoch 21/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8661 - val_accuracy: 0.8333
# Epoch 22/50
# 45/45 [==============================] - 0s 6ms/step - loss: 8.3774e-04 - accuracy: 1.0000 - val_loss: 0.8707 - val_accuracy: 0.8333
# Epoch 23/50
# 45/45 [==============================] - 0s 5ms/step - loss: 7.8705e-04 - accuracy: 1.0000 - val_loss: 0.8722 - val_accuracy: 0.8278
# Epoch 24/50
# 45/45 [==============================] - 0s 6ms/step - loss: 7.1948e-04 - accuracy: 1.0000 - val_loss: 0.8839 - val_accuracy: 0.8278
# Epoch 25/50
# 45/45 [==============================] - 0s 6ms/step - loss: 7.1326e-04 - accuracy: 1.0000 - val_loss: 0.8701 - val_accuracy: 0.8222
# Epoch 26/50
# 45/45 [==============================] - 0s 6ms/step - loss: 5.7471e-04 - accuracy: 1.0000 - val_loss: 0.8754 - val_accuracy: 0.8278
# Epoch 27/50
# 45/45 [==============================] - 0s 6ms/step - loss: 4.9026e-04 - accuracy: 1.0000 - val_loss: 0.8826 - val_accuracy: 0.8278
# Epoch 28/50
# 45/45 [==============================] - 0s 6ms/step - loss: 5.0577e-04 - accuracy: 1.0000 - val_loss: 0.8892 - val_accuracy: 0.8222
# Epoch 29/50
# 45/45 [==============================] - 0s 6ms/step - loss: 5.3617e-04 - accuracy: 1.0000 - val_loss: 0.8865 - val_accuracy: 0.8222
# Epoch 30/50
# 45/45 [==============================] - 0s 6ms/step - loss: 4.6081e-04 - accuracy: 1.0000 - val_loss: 0.8900 - val_accuracy: 0.8222
# Epoch 31/50
# 45/45 [==============================] - 0s 7ms/step - loss: 5.4649e-04 - accuracy: 1.0000 - val_loss: 0.8860 - val_accuracy: 0.8278
# Epoch 32/50
# 45/45 [==============================] - 0s 6ms/step - loss: 4.1187e-04 - accuracy: 1.0000 - val_loss: 0.8918 - val_accuracy: 0.8278
# Epoch 33/50
# 45/45 [==============================] - 0s 6ms/step - loss: 3.9319e-04 - accuracy: 1.0000 - val_loss: 0.9027 - val_accuracy: 0.8222
# Epoch 34/50
# 45/45 [==============================] - 0s 6ms/step - loss: 3.5506e-04 - accuracy: 1.0000 - val_loss: 0.9098 - val_accuracy: 0.8222
# Epoch 35/50
# 45/45 [==============================] - 0s 6ms/step - loss: 4.2352e-04 - accuracy: 1.0000 - val_loss: 0.9176 - val_accuracy: 0.8222
# Epoch 36/50
# 45/45 [==============================] - 0s 6ms/step - loss: 4.2765e-04 - accuracy: 1.0000 - val_loss: 0.9253 - val_accuracy: 0.8222
# Epoch 37/50
# 45/45 [==============================] - 0s 6ms/step - loss: 3.5366e-04 - accuracy: 1.0000 - val_loss: 0.9220 - val_accuracy: 0.8278
# Epoch 38/50
# 45/45 [==============================] - 0s 6ms/step - loss: 3.3788e-04 - accuracy: 1.0000 - val_loss: 0.9224 - val_accuracy: 0.8222
# Epoch 39/50
# 45/45 [==============================] - 0s 6ms/step - loss: 2.8010e-04 - accuracy: 1.0000 - val_loss: 0.9217 - val_accuracy: 0.8167
# Epoch 40/50
# 45/45 [==============================] - 0s 6ms/step - loss: 2.8091e-04 - accuracy: 1.0000 - val_loss: 0.9223 - val_accuracy: 0.8222
# Epoch 41/50
# 45/45 [==============================] - 0s 6ms/step - loss: 3.5919e-04 - accuracy: 1.0000 - val_loss: 0.9293 - val_accuracy: 0.8222
# Epoch 42/50
# 45/45 [==============================] - 0s 5ms/step - loss: 2.8000e-04 - accuracy: 1.0000 - val_loss: 0.9401 - val_accuracy: 0.8222
# Epoch 43/50
# 45/45 [==============================] - 0s 5ms/step - loss: 3.0653e-04 - accuracy: 1.0000 - val_loss: 0.9345 - val_accuracy: 0.8222
# Epoch 44/50
# 45/45 [==============================] - 0s 5ms/step - loss: 2.6282e-04 - accuracy: 1.0000 - val_loss: 0.9335 - val_accuracy: 0.8222
# Epoch 45/50
# 45/45 [==============================] - 0s 5ms/step - loss: 2.6260e-04 - accuracy: 1.0000 - val_loss: 0.9385 - val_accuracy: 0.8222
# Epoch 46/50
# 45/45 [==============================] - 0s 5ms/step - loss: 3.1466e-04 - accuracy: 1.0000 - val_loss: 0.9361 - val_accuracy: 0.8222
# Epoch 47/50
# 45/45 [==============================] - 0s 6ms/step - loss: 2.2806e-04 - accuracy: 1.0000 - val_loss: 0.9361 - val_accuracy: 0.8222
# Epoch 48/50
# 45/45 [==============================] - 0s 7ms/step - loss: 2.2102e-04 - accuracy: 1.0000 - val_loss: 0.9389 - val_accuracy: 0.8222
# Epoch 49/50
# 45/45 [==============================] - 0s 6ms/step - loss: 2.9533e-04 - accuracy: 1.0000 - val_loss: 0.9400 - val_accuracy: 0.8222
# Epoch 50/50
# 45/45 [==============================] - 0s 6ms/step - loss: 2.3201e-04 - accuracy: 1.0000 - val_loss: 0.9359 - val_accuracy: 0.8278
# Average validation accuracy of the 5 best epochs:  0.8355555415153504

# %% [markdown]
# - Try changing the number of layers in the network, also try changing the number of kernels or their sizes (take inspiration from the more complex modles we saw on class)
#
# - Does changing the number of layers and changing the kernel sizes/numbers improved the result or not? explain why?

# %% [markdown]
# <font color="#FFD629">
# <b><u> Increase pooling kernel size: </b></u>
# </font>

# %%
# Define the model
model3 = Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64,64,1)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(5,5)),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(5,5)),
    Flatten(),
    Dense(units=256, activation='relu'),
    Dense(units=4, activation='softmax')
])
print(model3.summary())
sgd_momentum = SGD(learning_rate=0.005, momentum=0.9)
model3.compile(optimizer=sgd_momentum, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history3 = model3.fit(x_train, y_train, epochs=50, batch_size=16, validation_data=(x_test, y_test))

print_avrg_val_acc(history3)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 62, 62, 32)        320
#
#  batch_normalization_2 (Batc  (None, 62, 62, 32)       128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 64)        18496
#
#  batch_normalization_3 (Batc  (None, 10, 10, 64)       256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 86,020
# Trainable params: 85,828
# Non-trainable params: 192
# _________________________________________________________________
# None
# Epoch 1/50
# 45/45 [==============================] - 2s 11ms/step - loss: 1.1662 - accuracy: 0.5810 - val_loss: 1.3250 - val_accuracy: 0.2722
# Epoch 2/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.7518 - accuracy: 0.6955 - val_loss: 1.1588 - val_accuracy: 0.5278
# Epoch 3/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5833 - accuracy: 0.7891 - val_loss: 1.0869 - val_accuracy: 0.6056
# Epoch 4/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5768 - accuracy: 0.7626 - val_loss: 1.0033 - val_accuracy: 0.6111
# Epoch 5/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5057 - accuracy: 0.8184 - val_loss: 0.9071 - val_accuracy: 0.5722
# Epoch 6/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4127 - accuracy: 0.8589 - val_loss: 1.1658 - val_accuracy: 0.5611
# Epoch 7/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4575 - accuracy: 0.8296 - val_loss: 0.8033 - val_accuracy: 0.6556
# Epoch 8/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3531 - accuracy: 0.8659 - val_loss: 0.6218 - val_accuracy: 0.7444
# Epoch 9/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4453 - accuracy: 0.8240 - val_loss: 0.5993 - val_accuracy: 0.7667
# Epoch 10/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.3190 - accuracy: 0.8715 - val_loss: 0.6556 - val_accuracy: 0.7222
# Epoch 11/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.3140 - accuracy: 0.8687 - val_loss: 0.5041 - val_accuracy: 0.7722
# Epoch 12/50
# 45/45 [==============================] - 0s 9ms/step - loss: 0.2180 - accuracy: 0.9204 - val_loss: 0.4426 - val_accuracy: 0.8111
# Epoch 13/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1925 - accuracy: 0.9288 - val_loss: 0.4871 - val_accuracy: 0.8000
# Epoch 14/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.1689 - accuracy: 0.9330 - val_loss: 0.5819 - val_accuracy: 0.7611
# Epoch 15/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.1516 - accuracy: 0.9483 - val_loss: 0.7190 - val_accuracy: 0.7278
# Epoch 16/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.1805 - accuracy: 0.9358 - val_loss: 0.7876 - val_accuracy: 0.7556
# Epoch 17/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1245 - accuracy: 0.9511 - val_loss: 0.6032 - val_accuracy: 0.7944
# Epoch 18/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1091 - accuracy: 0.9623 - val_loss: 1.8518 - val_accuracy: 0.5556
# Epoch 19/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1222 - accuracy: 0.9483 - val_loss: 0.5367 - val_accuracy: 0.8167
# Epoch 20/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.1080 - accuracy: 0.9637 - val_loss: 0.8037 - val_accuracy: 0.7556
# Epoch 21/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0695 - accuracy: 0.9804 - val_loss: 0.4832 - val_accuracy: 0.8500
# Epoch 22/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0311 - accuracy: 0.9958 - val_loss: 0.5862 - val_accuracy: 0.7944
# Epoch 23/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0463 - accuracy: 0.9916 - val_loss: 0.5735 - val_accuracy: 0.8167
# Epoch 24/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0710 - accuracy: 0.9777 - val_loss: 0.7278 - val_accuracy: 0.7778
# Epoch 25/50
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0577 - accuracy: 0.9763 - val_loss: 0.9650 - val_accuracy: 0.7611
# Epoch 26/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0608 - accuracy: 0.9763 - val_loss: 0.6905 - val_accuracy: 0.7833
# Epoch 27/50
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0380 - accuracy: 0.9916 - val_loss: 0.7065 - val_accuracy: 0.8111
# Epoch 28/50
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0506 - accuracy: 0.9832 - val_loss: 0.6677 - val_accuracy: 0.8333
# Epoch 29/50
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0354 - accuracy: 0.9874 - val_loss: 0.5367 - val_accuracy: 0.8556
# Epoch 30/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0164 - accuracy: 0.9986 - val_loss: 0.6129 - val_accuracy: 0.8389
# Epoch 31/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 0.9944 - val_loss: 0.7015 - val_accuracy: 0.7833
# Epoch 32/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5973 - val_accuracy: 0.8333
# Epoch 33/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.6218 - val_accuracy: 0.8222
# Epoch 34/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6348 - val_accuracy: 0.8389
# Epoch 35/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.5630 - val_accuracy: 0.8444
# Epoch 36/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.6074 - val_accuracy: 0.8333
# Epoch 37/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.6417 - val_accuracy: 0.8556
# Epoch 38/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.6301 - val_accuracy: 0.8444
# Epoch 39/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6310 - val_accuracy: 0.8444
# Epoch 40/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6153 - val_accuracy: 0.8389
# Epoch 41/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6504 - val_accuracy: 0.8444
# Epoch 42/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6317 - val_accuracy: 0.8500
# Epoch 43/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6181 - val_accuracy: 0.8444
# Epoch 44/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6392 - val_accuracy: 0.8444
# Epoch 45/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6655 - val_accuracy: 0.8389
# Epoch 46/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6480 - val_accuracy: 0.8333
# Epoch 47/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7106 - val_accuracy: 0.8389
# Epoch 48/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6530 - val_accuracy: 0.8444
# Epoch 49/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6576 - val_accuracy: 0.8500
# Epoch 50/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6361 - val_accuracy: 0.8556
# Average validation accuracy of the 5 best epochs:  0.8533333301544189

# %% [markdown]
# <font color="#5fbefe">
# When we increased the MaxPooling kernel size we got better results. The kernel size determines the size of the region over which the maximum value is calculated, so when we set hte kernel bigger the window calculates the maximum value over larger regions of the input image, which helps to retain more information and detail. This can lead to better performance in some cases, but it may also result in a larger output size and slower computation
# </font>

# %% [markdown]
# <font color="#FFD629">
# Increase number of layers:
# </font>

# %%
# Define the model
model4 = Sequential([
    Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=(64,64,1)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=256, kernel_size=(3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=512, kernel_size=(3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(units=1024, activation='relu'),
    Dense(units=4, activation='softmax')
])
print(model4.summary())
sgd_momentum = SGD(learning_rate=0.01, momentum=0.9)
model4.compile(optimizer=sgd_momentum, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history4 = model4.fit(x_train, y_train, epochs=50, batch_size=16, validation_data=(x_test, y_test))

print_avrg_val_acc(history4)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 62, 62, 64)        640
#
#  batch_normalization_16 (Bat  (None, 62, 62, 64)       256
#  chNormalization)
#
#  max_pooling2d_20 (MaxPoolin  (None, 31, 31, 64)       0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 29, 29, 128)       73856
#
#  batch_normalization_17 (Bat  (None, 29, 29, 128)      512
#  chNormalization)
#
#  max_pooling2d_21 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 12, 12, 256)       295168
#
#  batch_normalization_18 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  max_pooling2d_22 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  batch_normalization_19 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  max_pooling2d_23 (MaxPoolin  (None, 2, 2, 512)        0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 2048)              0
#
#  dense_18 (Dense)            (None, 1024)              2098176
#
#  dense_19 (Dense)            (None, 4)                 4100
#
# =================================================================
# Total params: 3,655,940
# Trainable params: 3,654,020
# Non-trainable params: 1,920
# _________________________________________________________________
# None
# Epoch 1/50
# 45/45 [==============================] - 2s 17ms/step - loss: 1.8089 - accuracy: 0.5433 - val_loss: 11.3031 - val_accuracy: 0.2722
# Epoch 2/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.8525 - accuracy: 0.7039 - val_loss: 1.1225 - val_accuracy: 0.5278
# Epoch 3/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.6704 - accuracy: 0.7570 - val_loss: 1.7626 - val_accuracy: 0.5056
# Epoch 4/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.6232 - accuracy: 0.7668 - val_loss: 0.9893 - val_accuracy: 0.6556
# Epoch 5/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.5287 - accuracy: 0.8073 - val_loss: 1.0685 - val_accuracy: 0.6556
# Epoch 6/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.5334 - accuracy: 0.8073 - val_loss: 0.9744 - val_accuracy: 0.7000
# Epoch 7/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.5175 - accuracy: 0.8226 - val_loss: 1.5709 - val_accuracy: 0.5889
# Epoch 8/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.3994 - accuracy: 0.8492 - val_loss: 1.1210 - val_accuracy: 0.7056
# Epoch 9/50
# 45/45 [==============================] - 0s 9ms/step - loss: 0.3648 - accuracy: 0.8436 - val_loss: 0.8383 - val_accuracy: 0.7722
# Epoch 10/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.4057 - accuracy: 0.8506 - val_loss: 0.7615 - val_accuracy: 0.7889
# Epoch 11/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2910 - accuracy: 0.9022 - val_loss: 0.9428 - val_accuracy: 0.7444
# Epoch 12/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2293 - accuracy: 0.9148 - val_loss: 1.0657 - val_accuracy: 0.7556
# Epoch 13/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2217 - accuracy: 0.9260 - val_loss: 0.8019 - val_accuracy: 0.7722
# Epoch 14/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.3286 - accuracy: 0.8939 - val_loss: 1.2013 - val_accuracy: 0.7722
# Epoch 15/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.4489 - accuracy: 0.8589 - val_loss: 0.7404 - val_accuracy: 0.7167
# Epoch 16/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.3370 - accuracy: 0.8771 - val_loss: 0.8682 - val_accuracy: 0.7944
# Epoch 17/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2698 - accuracy: 0.9008 - val_loss: 0.8077 - val_accuracy: 0.7833
# Epoch 18/50
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1660 - accuracy: 0.9399 - val_loss: 0.9407 - val_accuracy: 0.8000
# Epoch 19/50
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1443 - accuracy: 0.9539 - val_loss: 0.7191 - val_accuracy: 0.8111
# Epoch 20/50
# 45/45 [==============================] - 1s 11ms/step - loss: 0.1855 - accuracy: 0.9372 - val_loss: 0.7518 - val_accuracy: 0.8500
# Epoch 21/50
# 45/45 [==============================] - 1s 12ms/step - loss: 0.2747 - accuracy: 0.9176 - val_loss: 1.0452 - val_accuracy: 0.8000
# Epoch 22/50
# 45/45 [==============================] - 0s 11ms/step - loss: 0.2553 - accuracy: 0.9176 - val_loss: 0.7042 - val_accuracy: 0.8000
# Epoch 23/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2611 - accuracy: 0.9176 - val_loss: 1.1014 - val_accuracy: 0.7667
# Epoch 24/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1078 - accuracy: 0.9483 - val_loss: 1.2570 - val_accuracy: 0.7833
# Epoch 25/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1264 - accuracy: 0.9567 - val_loss: 1.0804 - val_accuracy: 0.7722
# Epoch 26/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1129 - accuracy: 0.9637 - val_loss: 1.0346 - val_accuracy: 0.8222
# Epoch 27/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1134 - accuracy: 0.9623 - val_loss: 1.3470 - val_accuracy: 0.8111
# Epoch 28/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0936 - accuracy: 0.9595 - val_loss: 0.9046 - val_accuracy: 0.8389
# Epoch 29/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1186 - accuracy: 0.9651 - val_loss: 1.4473 - val_accuracy: 0.8111
# Epoch 30/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1070 - accuracy: 0.9735 - val_loss: 1.1736 - val_accuracy: 0.8222
# Epoch 31/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0942 - accuracy: 0.9777 - val_loss: 0.8890 - val_accuracy: 0.8167
# Epoch 32/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0586 - accuracy: 0.9860 - val_loss: 1.2396 - val_accuracy: 0.8111
# Epoch 33/50
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0504 - accuracy: 0.9888 - val_loss: 1.0319 - val_accuracy: 0.8389
# Epoch 34/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0152 - accuracy: 0.9930 - val_loss: 1.0186 - val_accuracy: 0.8389
# Epoch 35/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0478 - accuracy: 0.9874 - val_loss: 1.0454 - val_accuracy: 0.8222
# Epoch 36/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0456 - accuracy: 0.9874 - val_loss: 1.0368 - val_accuracy: 0.8444
# Epoch 37/50
# 45/45 [==============================] - 0s 11ms/step - loss: 0.1130 - accuracy: 0.9693 - val_loss: 1.1927 - val_accuracy: 0.8056
# Epoch 38/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0972 - accuracy: 0.9735 - val_loss: 1.4950 - val_accuracy: 0.7944
# Epoch 39/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0515 - accuracy: 0.9818 - val_loss: 1.2904 - val_accuracy: 0.8111
# Epoch 40/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0586 - accuracy: 0.9818 - val_loss: 1.2891 - val_accuracy: 0.8000
# Epoch 41/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0337 - accuracy: 0.9874 - val_loss: 1.1000 - val_accuracy: 0.8167
# Epoch 42/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0315 - accuracy: 0.9860 - val_loss: 1.2127 - val_accuracy: 0.8056
# Epoch 43/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0590 - accuracy: 0.9874 - val_loss: 1.2988 - val_accuracy: 0.8222
# Epoch 44/50
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0357 - accuracy: 0.9860 - val_loss: 1.1123 - val_accuracy: 0.8333
# Epoch 45/50
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0254 - accuracy: 0.9916 - val_loss: 1.2823 - val_accuracy: 0.8389
# Epoch 46/50
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 1.2750 - val_accuracy: 0.8222
# Epoch 47/50
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0153 - accuracy: 0.9958 - val_loss: 1.2430 - val_accuracy: 0.8500
# Epoch 48/50
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2570 - val_accuracy: 0.8167
# Epoch 49/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0024 - accuracy: 0.9986 - val_loss: 1.0749 - val_accuracy: 0.8500
# Epoch 50/50
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0023 - accuracy: 0.9986 - val_loss: 1.4988 - val_accuracy: 0.8444
# Average validation accuracy of the 5 best epochs:  0.8477777957916259

# %% [markdown]
# <font color="#5fbefe">
# Here we got better results than the simple 5 layer model with the 3x3 pool kernel, but worse than the results of the 5x5 pool kernel.
# The result is better than the simple model because it uses more layers and can detect more variance in our images correctly, but, because of the higher number of layers the model became more complex and starts to fit the training data more than the simple model with the 5x5 pooling kernel.
# </font>

# %% [markdown]
# # 2. Using augmentation
#
# - Try using augmentation, even if its not helpful and you get worst results don't worry about it, we are just experimenting.
#
# - Read the description in this link: https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
# (in the section titled "Data pre-processing and data augmentation") to understand better how to use augmentation in Keras (along side what we studied at class).
#
# - Choose reasonable values for the augmentation considring the data we  are working on, for example rotation_range = 180 is not reasonable since we are not expected to recieve a flipped X-ray image.
#
# - If you want to look at the X-ray images in the data you can download them from here:
# http://dl.dropboxusercontent.com/s/6hq5t0sbbx6n1g2/medical_xray.zip?dl=0
# Or you can look at the environment files in Google Colab after running the second cell (double click on an image to view it).

# %%
# We will use a model with batch normalization and 5x5 pooling kernel because 
# it had the best results
model = Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64,64,1)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(5,5)),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(5,5)),
    Flatten(),
    Dense(units=256, activation='relu'),
    Dense(units=4, activation='softmax')
])

sgd_momentum = SGD(learning_rate=0.005, momentum=0.9)
model.compile(optimizer=sgd_momentum, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
    )

data_iter = datagen.flow(x_train, y_train, batch_size=32)

history = model.fit(data_iter, steps_per_epoch=x_train.shape[0]//32, epochs=50, 
                    validation_data=(x_test, y_test), verbose=0)

print_avrg_val_acc(history)
# Out:
# Average validation accuracy of the 5 best epochs:  0.8144444346427917

# %% [markdown]
# ## Good Luck!
